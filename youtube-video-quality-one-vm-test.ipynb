# %% [markdown]
# # Measurements of all suggested quality and player size combinations over UDP against Adguard DNS server on the test VM only -- 3 videos

# %%
import pandas as pd
import sqlite3
import datetime
import numpy as np
import matplotlib as mpl
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib.ticker import PercentFormatter
import math
import Cdf
import Pmf
mpl.rcParams['figure.dpi'] = 200
okabe_ito = ["#000000", "#E69F00", "#56B4E9", "#009E73", "#F0E442", "#0072B2", "#D55E00", "#CC79A7"]
sns.set_context('paper')
sns.set_palette(sns.color_palette(okabe_ito))
#https://stackoverflow.com/a/45846841
def human_format(num):
    num = float('{:.3g}'.format(num))
    magnitude = 0
    while abs(num) >= 1000:
        magnitude += 1
        num /= 1000.0
    return '{}{}'.format('{:f}'.format(num).rstrip('0').rstrip('.'), ['', 'K', 'M', 'B', 'T'][magnitude])
def make_cdf(series):
    return series.value_counts(normalize=True).sort_index().cumsum()
def make_pdf(series):
    return series.value_counts(normalize=True).sort_index()

# %%
conn = sqlite3.connect('../web-performance/web-performance-youtube-suggested-quality-dataset')
measurements = pd.read_sql_query("SELECT * FROM measurements", conn)
measurements
#conn.close()
# Out:
#                                    msm_id              py_time       js_time  \
# 0    24fdef1c-a087-9736-abf0-4913a80e3f88  1645035501654826015  1.645036e+12
# 1    7618731e-77bb-398c-804f-8749bd91e64e  1645035536935937261  1.645036e+12
# 2    08a69630-1ba1-f7b7-9772-85bab6baa8bd  1645035545470292046  1.645036e+12
# 3    72a7b5e0-9b49-0569-7eb7-bfe57806c0af  1645035580702717686  1.645036e+12
# 4    71f797b6-e500-e0e3-b922-41aca902dd43  1645035593619247412  1.645036e+12
# ..                                    ...                  ...           ...
# 601  588a971c-87c2-5f5c-e0d5-795b7aa4c308  1645049192431194860  1.645049e+12
# 602  1ab93042-62b8-1d71-b39b-291b3f0520b7  1645049200465561237  1.645049e+12
# 603  d00dd8dc-b80c-54f1-d80c-678f8c42ff6f  1645049236076280394  1.645049e+12
# 604  88557a9e-8aae-37f8-0380-fd547aac23eb  1645049244965274381  1.645049e+12
# 605  9ad2baf1-6ac9-0f76-2bb2-22a64f50c21d  1645049280403697013  1.645049e+12
#
#      resource_time_origin protocol         server       domain vantagePoint  \
# 0            1.645035e+12      udp  94.140.14.140  aqz-KE-bpKQ
# 1            1.645036e+12      udp  94.140.14.140  aqz-KE-bpKQ
# 2            1.645036e+12      udp  94.140.14.140  lqiN98z6Dak
# 3            1.645036e+12      udp  94.140.14.140  lqiN98z6Dak
# 4            1.645036e+12      udp  94.140.14.140  aqz-KE-bpKQ
# ..                    ...      ...            ...          ...          ...
# 601          1.645049e+12      udp  94.140.14.140  aqz-KE-bpKQ
# 602          1.645049e+12      udp  94.140.14.140  lqiN98z6Dak
# 603          1.645049e+12      udp  94.140.14.140  lqiN98z6Dak
# 604          1.645049e+12      udp  94.140.14.140  RJnKaAtBPhA
# 605          1.645049e+12      udp  94.140.14.140  RJnKaAtBPhA
#
#                       timestamp suggested_quality  player_width  \
# 0    2022-02-16 18:18:15.390571              auto           256
# 1    2022-02-16 18:18:23.047468              auto           256
# 2    2022-02-16 18:18:58.724641              auto           256
# 3    2022-02-16 18:19:06.852357              auto           256
# 4    2022-02-16 18:19:47.403376              tiny           256
# ..                          ...               ...           ...
# 601  2022-02-16 22:05:58.047199            hd2160          3840
# 602  2022-02-16 22:06:34.294722            hd2160          3840
# 603  2022-02-16 22:06:41.855754            hd2160          3840
# 604  2022-02-16 22:07:18.893514            hd2160          3840
# 605  2022-02-16 22:07:26.344852            hd2160          3840
#
#      player_height  start_time  play_time  \
# 0              144           0         30
# 1              144           0         30
# 2              144           0         30
# 3              144           0         30
# 4              144           0         30
# ..             ...         ...        ...
# 601           2160           0         30
# 602           2160           0         30
# 603           2160           0         30
# 604           2160           0         30
# 605           2160           0         30
#
#                                  video_ids  cacheWarming error
# 0    aqz-KE-bpKQ, lqiN98z6Dak, RJnKaAtBPhA             1
# 1    aqz-KE-bpKQ, lqiN98z6Dak, RJnKaAtBPhA             0
# 2    aqz-KE-bpKQ, lqiN98z6Dak, RJnKaAtBPhA             1
# 3    aqz-KE-bpKQ, lqiN98z6Dak, RJnKaAtBPhA             0
# 4    aqz-KE-bpKQ, lqiN98z6Dak, RJnKaAtBPhA             1
# ..                                     ...           ...   ...
# 601  aqz-KE-bpKQ, lqiN98z6Dak, RJnKaAtBPhA             0
# 602  aqz-KE-bpKQ, lqiN98z6Dak, RJnKaAtBPhA             1
# 603  aqz-KE-bpKQ, lqiN98z6Dak, RJnKaAtBPhA             0
# 604  aqz-KE-bpKQ, lqiN98z6Dak, RJnKaAtBPhA             1
# 605  aqz-KE-bpKQ, lqiN98z6Dak, RJnKaAtBPhA             0
#
# [606 rows x 17 columns]

# %%
measurements.dtypes
# Out:
# msm_id                   object
# py_time                   int64
# js_time                 float64
# resource_time_origin    float64
# protocol                 object
# server                   object
# domain                   object
# vantagePoint             object
# timestamp                object
# suggested_quality        object
# player_width              int64
# player_height             int64
# start_time                int64
# play_time                 int64
# video_ids                object
# cacheWarming              int64
# error                    object
# dtype: object

# %%
measurements['js_time'] = pd.to_datetime(measurements['js_time'], unit='ms', origin='unix')

# %%
measurements['resource_time_origin'] = pd.to_datetime(measurements['resource_time_origin'], unit='ms', origin='unix')

# %%
measurements['py_time'] = pd.to_datetime(measurements['py_time'], unit='ns', origin='unix')

# %%
measurements['timestamp'] = pd.to_datetime(measurements['timestamp'])

# %%
measurements[measurements.error != ""].error.unique()
# Out:
# array(['failed loading player ### Message: javascript error: player.cueVideoById is not a function\n  (Session info: headless chrome=98.0.4758.80)\nStacktrace:\n#0 0x563579225113 <unknown>\n#1 0x563578ced6d8 <unknown>\n#2 0x563578cf055c <unknown>\n#3 0x563578cf0356 <unknown>\n#4 0x563578cf0ef2 <unknown>\n#5 0x563578d55523 <unknown>\n#6 0x563578d41062 <unknown>\n#7 0x563578d5490b <unknown>\n#8 0x563578d40f53 <unknown>\n#9 0x563578d16bda <unknown>\n#10 0x563578d17ca5 <unknown>\n#11 0x5635792568dd <unknown>\n#12 0x56357926fa9b <unknown>\n#13 0x5635792586b5 <unknown>\n#14 0x563579270725 <unknown>\n#15 0x56357924c08f <unknown>\n#16 0x56357928d188 <unknown>\n#17 0x56357928d308 <unknown>\n#18 0x5635792a7a6d <unknown>\n#19 0x7f6953441609 <unknown>\n',
#        'failed loading player ### Message: javascript error: player.cueVideoById is not a function\n  (Session info: headless chrome=98.0.4758.80)\nStacktrace:\n#0 0x56044473c113 <unknown>\n#1 0x5604442046d8 <unknown>\n#2 0x56044420755c <unknown>\n#3 0x560444207356 <unknown>\n#4 0x560444207ef2 <unknown>\n#5 0x56044426c523 <unknown>\n#6 0x560444258062 <unknown>\n#7 0x56044426b90b <unknown>\n#8 0x560444257f53 <unknown>\n#9 0x56044422dbda <unknown>\n#10 0x56044422eca5 <unknown>\n#11 0x56044476d8dd <unknown>\n#12 0x560444786a9b <unknown>\n#13 0x56044476f6b5 <unknown>\n#14 0x560444787725 <unknown>\n#15 0x56044476308f <unknown>\n#16 0x5604447a4188 <unknown>\n#17 0x5604447a4308 <unknown>\n#18 0x5604447bea6d <unknown>\n#19 0x7f814958b609 <unknown>\n',
#        'failed loading player ### Message: javascript error: player.cueVideoById is not a function\n  (Session info: headless chrome=98.0.4758.80)\nStacktrace:\n#0 0x560b13601113 <unknown>\n#1 0x560b130c96d8 <unknown>\n#2 0x560b130cc55c <unknown>\n#3 0x560b130cc356 <unknown>\n#4 0x560b130ccef2 <unknown>\n#5 0x560b13131523 <unknown>\n#6 0x560b1311d062 <unknown>\n#7 0x560b1313090b <unknown>\n#8 0x560b1311cf53 <unknown>\n#9 0x560b130f2bda <unknown>\n#10 0x560b130f3ca5 <unknown>\n#11 0x560b136328dd <unknown>\n#12 0x560b1364ba9b <unknown>\n#13 0x560b136346b5 <unknown>\n#14 0x560b1364c725 <unknown>\n#15 0x560b1362808f <unknown>\n#16 0x560b13669188 <unknown>\n#17 0x560b13669308 <unknown>\n#18 0x560b13683a6d <unknown>\n#19 0x7fc27f45a609 <unknown>\n',
#        'failed loading player ### Message: javascript error: player.cueVideoById is not a function\n  (Session info: headless chrome=98.0.4758.80)\nStacktrace:\n#0 0x562b1b18b113 <unknown>\n#1 0x562b1ac536d8 <unknown>\n#2 0x562b1ac5655c <unknown>\n#3 0x562b1ac56356 <unknown>\n#4 0x562b1ac56ef2 <unknown>\n#5 0x562b1acbb523 <unknown>\n#6 0x562b1aca7062 <unknown>\n#7 0x562b1acba90b <unknown>\n#8 0x562b1aca6f53 <unknown>\n#9 0x562b1ac7cbda <unknown>\n#10 0x562b1ac7dca5 <unknown>\n#11 0x562b1b1bc8dd <unknown>\n#12 0x562b1b1d5a9b <unknown>\n#13 0x562b1b1be6b5 <unknown>\n#14 0x562b1b1d6725 <unknown>\n#15 0x562b1b1b208f <unknown>\n#16 0x562b1b1f3188 <unknown>\n#17 0x562b1b1f3308 <unknown>\n#18 0x562b1b20da6d <unknown>\n#19 0x7fdb4b760609 <unknown>\n',
#        'failed loading player ### Message: javascript error: player.cueVideoById is not a function\n  (Session info: headless chrome=98.0.4758.80)\nStacktrace:\n#0 0x558340387113 <unknown>\n#1 0x55833fe4f6d8 <unknown>\n#2 0x55833fe5255c <unknown>\n#3 0x55833fe52356 <unknown>\n#4 0x55833fe52ef2 <unknown>\n#5 0x55833feb7523 <unknown>\n#6 0x55833fea3062 <unknown>\n#7 0x55833feb690b <unknown>\n#8 0x55833fea2f53 <unknown>\n#9 0x55833fe78bda <unknown>\n#10 0x55833fe79ca5 <unknown>\n#11 0x5583403b88dd <unknown>\n#12 0x5583403d1a9b <unknown>\n#13 0x5583403ba6b5 <unknown>\n#14 0x5583403d2725 <unknown>\n#15 0x5583403ae08f <unknown>\n#16 0x5583403ef188 <unknown>\n#17 0x5583403ef308 <unknown>\n#18 0x558340409a6d <unknown>\n#19 0x7fdda1cba609 <unknown>\n',
#        'failed loading player ### Message: javascript error: player.cueVideoById is not a function\n  (Session info: headless chrome=98.0.4758.80)\nStacktrace:\n#0 0x56342d41a113 <unknown>\n#1 0x56342cee26d8 <unknown>\n#2 0x56342cee555c <unknown>\n#3 0x56342cee5356 <unknown>\n#4 0x56342cee5ef2 <unknown>\n#5 0x56342cf4a523 <unknown>\n#6 0x56342cf36062 <unknown>\n#7 0x56342cf4990b <unknown>\n#8 0x56342cf35f53 <unknown>\n#9 0x56342cf0bbda <unknown>\n#10 0x56342cf0cca5 <unknown>\n#11 0x56342d44b8dd <unknown>\n#12 0x56342d464a9b <unknown>\n#13 0x56342d44d6b5 <unknown>\n#14 0x56342d465725 <unknown>\n#15 0x56342d44108f <unknown>\n#16 0x56342d482188 <unknown>\n#17 0x56342d482308 <unknown>\n#18 0x56342d49ca6d <unknown>\n#19 0x7f5c2b11c609 <unknown>\n',
#        'failed loading player ### Message: javascript error: player.cueVideoById is not a function\n  (Session info: headless chrome=98.0.4758.80)\nStacktrace:\n#0 0x55a1e69fe113 <unknown>\n#1 0x55a1e64c66d8 <unknown>\n#2 0x55a1e64c955c <unknown>\n#3 0x55a1e64c9356 <unknown>\n#4 0x55a1e64c9ef2 <unknown>\n#5 0x55a1e652e523 <unknown>\n#6 0x55a1e651a062 <unknown>\n#7 0x55a1e652d90b <unknown>\n#8 0x55a1e6519f53 <unknown>\n#9 0x55a1e64efbda <unknown>\n#10 0x55a1e64f0ca5 <unknown>\n#11 0x55a1e6a2f8dd <unknown>\n#12 0x55a1e6a48a9b <unknown>\n#13 0x55a1e6a316b5 <unknown>\n#14 0x55a1e6a49725 <unknown>\n#15 0x55a1e6a2508f <unknown>\n#16 0x55a1e6a66188 <unknown>\n#17 0x55a1e6a66308 <unknown>\n#18 0x55a1e6a80a6d <unknown>\n#19 0x7f5993b98609 <unknown>\n'],
#       dtype=object)

# %%
df_start_time = pd.read_sql_query("""
SELECT start_time, play_time, msm_id, current_quality FROM
(SELECT time AS start_time, msm_id FROM iframe_api WHERE event_type = 'PlayStartedFromFunction')
JOIN
(SELECT time AS play_time, msm_id, current_quality FROM iframe_api WHERE event_type = 'PlayerStatePLAYING' AND curr_play_time < 1)
USING (msm_id);
""", conn)

# %%
df_start_time['start_time'] = pd.to_datetime(df_start_time['start_time'], unit='ms', origin='unix')
df_start_time['play_time'] = pd.to_datetime(df_start_time['play_time'], unit='ms', origin='unix')

# %%
df_start_time['startup_delay'] = (df_start_time['play_time'] - df_start_time['start_time']).dt.total_seconds()

# %%
df_start_time['current_quality'].value_counts()
# Out:
# medium    453
# hd1080     37
# large      31
# hd2160     28
# hd720      26
# hd1440     24
# Name: current_quality, dtype: int64

# %%
df_start_time.startup_delay.median()
# Out:
# 0.356199936

# %%
df_nerd_stats_resolutions = pd.read_sql_query("""
SELECT DISTINCT msm_id, resolution FROM nerd_stats
""", conn)

# %%
df_nerd_stats_resolutions.groupby('msm_id').agg({'resolution':pd.Series.nunique}).sort_values('resolution', ascending=False)
# Out:
#                                       resolution
# msm_id
# bc9d4921-134c-c6db-2929-80972ba6a250           4
# 6866ddd9-0ff7-0460-9b3e-c75893336992           4
# dd030ebf-be6e-2b9b-8308-40e1eab5b595           4
# 2b928bc1-6aac-a5d6-51f1-41c9543a44e5           4
# febc7d00-d261-9c5a-2f5f-6820f02b7409           3
# ...                                          ...
# 5a9b845a-0d7f-721b-1daa-5cf9bfa34526           1
# 5a3bd406-c87f-88ef-2287-28423b4493a7           1
# 593ebf72-987b-d137-5885-8a53f3823d0c           1
# 57b68083-dc3d-7d2c-c32f-25c5f3fe1adc           1
# ff8fa26c-1d72-e2a4-b858-4c2d87d11e5f           1
#
# [599 rows x 1 columns]

# %%
df_nerd_stats_resolutions[df_nerd_stats_resolutions.msm_id == 'bc9d4921-134c-c6db-2929-80972ba6a250']
# Out:
#                                    msm_id                   resolution
# 441  bc9d4921-134c-c6db-2929-80972ba6a250    640x360@60 / 3840x2160@60
# 442  bc9d4921-134c-c6db-2929-80972ba6a250  3840x2160@60 / 3840x2160@60
# 443  bc9d4921-134c-c6db-2929-80972ba6a250        0x0@60 / 2560x1440@60
# 444  bc9d4921-134c-c6db-2929-80972ba6a250  2560x1440@60 / 2560x1440@60

# %%
measurements['player_width'] = measurements['player_width'].astype(str)
measurements['player_height'] = measurements['player_height'].astype(str)
measurements['player_dimensions'] = measurements['player_width']+"x"+measurements['player_height']

# %%
df_nerd_stats_resolutions['current_res'] = df_nerd_stats_resolutions['resolution'].str.split(' / ').str[0]
df_nerd_stats_resolutions['current_res'] = df_nerd_stats_resolutions['current_res'].str.split('@').str[0]

df_nerd_stats_resolutions['optimal_res'] = df_nerd_stats_resolutions['resolution'].str.split(' / ').str[1]
df_nerd_stats_resolutions['optimal_res'] = df_nerd_stats_resolutions['optimal_res'].str.split('@').str[0]

# %%
df_nerd_stats_resolutions.groupby('msm_id').agg({'optimal_res':pd.Series.nunique})
# Out:
#                                       optimal_res
# msm_id
# 01146afa-d9e5-11de-5c84-bdeba93d6baa            1
# 017fcec0-8f5e-bd62-10ef-dfa723783913            1
# 02466ec0-e158-b65f-8141-25d5eba3b44c            1
# 0294d1e2-b57a-9e53-fe58-9a6a584d2b43            1
# 02b3f23d-44c8-dba4-db78-e19305198940            1
# ...                                           ...
# fe7afeba-46d4-cebe-321a-7fbca112c3f8            1
# febc7d00-d261-9c5a-2f5f-6820f02b7409            1
# feef096b-bef5-bf5e-c310-97aeaa097c17            1
# ff147411-8f64-18d3-3a4b-a7d30d3d0595            1
# ff8fa26c-1d72-e2a4-b858-4c2d87d11e5f            1
#
# [599 rows x 1 columns]

# %%
df_nerd_stats_with_meta = pd.merge(df_nerd_stats_resolutions, measurements[measurements.cacheWarming == 0][['msm_id', 'suggested_quality', 'player_dimensions', 'domain']], on='msm_id')

# %%
df_suggested_quality = df_nerd_stats_with_meta.groupby(['player_dimensions', 'suggested_quality'], as_index=False).agg({'current_res':lambda x: sorted(list(set(x)))})

# %%
df_suggested_quality['player_dimensions'] = pd.Categorical(df_suggested_quality['player_dimensions'], 
            ['256x144', '426x240', '640x360', '854x480', '1280x720', '1920x1080', '2560x1440', '3840x2160'])

# %%
df_suggested_quality['suggested_quality'] = pd.Categorical(df_suggested_quality['suggested_quality'], 
            ['auto', 'tiny', 'small', 'medium', 'large', 'hd720', 'hd1080', 'highres', 'hd1440', 'hd2160'])

# %%
pd.set_option('display.max_rows', 100)

# %%
df_suggested_quality.sort_values(['player_dimensions', 'suggested_quality'])
# Out:
#    player_dimensions suggested_quality  \
# 29           256x144              auto
# 38           256x144              tiny
# 37           256x144             small
# 36           256x144            medium
# 35           256x144             large
# 33           256x144             hd720
# 30           256x144            hd1080
# 34           256x144           highres
# 31           256x144            hd1440
# 32           256x144            hd2160
# 48           426x240              auto
# 57           426x240              tiny
# 56           426x240             small
# 55           426x240            medium
# 54           426x240             large
# 52           426x240             hd720
# 49           426x240            hd1080
# 53           426x240           highres
# 50           426x240            hd1440
# 51           426x240            hd2160
# 58           640x360              auto
# 67           640x360              tiny
# 66           640x360             small
# 65           640x360            medium
# 64           640x360             large
# 62           640x360             hd720
# 59           640x360            hd1080
# 63           640x360           highres
# 60           640x360            hd1440
# 61           640x360            hd2160
# 68           854x480              auto
# 76           854x480             small
# 75           854x480            medium
# 74           854x480             large
# 72           854x480             hd720
# 69           854x480            hd1080
# 73           854x480           highres
# 70           854x480            hd1440
# 71           854x480            hd2160
# 0           1280x720              auto
# 8           1280x720              tiny
# 7           1280x720             small
# 6           1280x720             large
# 4           1280x720             hd720
# 1           1280x720            hd1080
# 5           1280x720           highres
# 2           1280x720            hd1440
# 3           1280x720            hd2160
# 9          1920x1080              auto
# 18         1920x1080              tiny
# 17         1920x1080             small
# 16         1920x1080            medium
# 15         1920x1080             large
# 13         1920x1080             hd720
# 10         1920x1080            hd1080
# 14         1920x1080           highres
# 11         1920x1080            hd1440
# 12         1920x1080            hd2160
# 19         2560x1440              auto
# 28         2560x1440              tiny
# 27         2560x1440             small
# 26         2560x1440            medium
# 25         2560x1440             large
# 23         2560x1440             hd720
# 20         2560x1440            hd1080
# 24         2560x1440           highres
# 21         2560x1440            hd1440
# 22         2560x1440            hd2160
# 39         3840x2160              auto
# 47         3840x2160              tiny
# 46         3840x2160             small
# 45         3840x2160            medium
# 43         3840x2160             hd720
# 40         3840x2160            hd1080
# 44         3840x2160           highres
# 41         3840x2160            hd1440
# 42         3840x2160            hd2160
#
#                                       current_res
# 29                                      [640x360]
# 38                                      [640x360]
# 37                                      [640x360]
# 36                                      [640x360]
# 35                                      [640x360]
# 33                                 [0x0, 640x360]
# 30                                      [640x360]
# 34                                      [640x360]
# 31                                      [640x360]
# 32                                      [640x360]
# 48                             [426x240, 640x360]
# 57                                      [640x360]
# 56                                      [640x360]
# 55                                      [640x360]
# 54                                      [640x360]
# 52                                      [640x360]
# 49                                      [640x360]
# 53                                      [640x360]
# 50                                      [640x360]
# 51                                      [640x360]
# 58                                      [640x360]
# 67                                      [640x360]
# 66                                      [640x360]
# 65                                      [640x360]
# 64                                      [640x360]
# 62                                 [0x0, 640x360]
# 59                                      [640x360]
# 63                                      [640x360]
# 60                                      [640x360]
# 61                                      [640x360]
# 68                             [640x360, 854x480]
# 76                             [640x360, 854x480]
# 75                             [640x360, 854x480]
# 74                             [640x360, 854x480]
# 72                             [640x360, 854x480]
# 69                             [640x360, 854x480]
# 73                             [640x360, 854x480]
# 70                             [640x360, 854x480]
# 71                             [640x360, 854x480]
# 0                    [1280x720, 640x360, 854x480]
# 8                    [1280x720, 640x360, 854x480]
# 7                    [1280x720, 640x360, 854x480]
# 6                    [1280x720, 640x360, 854x480]
# 4                    [1280x720, 640x360, 854x480]
# 1                    [1280x720, 640x360, 854x480]
# 5                    [1280x720, 640x360, 854x480]
# 2                    [1280x720, 640x360, 854x480]
# 3                    [1280x720, 640x360, 854x480]
# 9                   [1920x1080, 640x360, 854x480]
# 18                  [1920x1080, 640x360, 854x480]
# 17                  [1920x1080, 640x360, 854x480]
# 16                  [1920x1080, 640x360, 854x480]
# 15                  [1920x1080, 640x360, 854x480]
# 13                  [1920x1080, 640x360, 854x480]
# 10             [0x0, 1920x1080, 640x360, 854x480]
# 14                  [1920x1080, 640x360, 854x480]
# 11                  [1920x1080, 640x360, 854x480]
# 12                  [1920x1080, 640x360, 854x480]
# 19                  [2560x1440, 640x360, 854x480]
# 28                  [2560x1440, 640x360, 854x480]
# 27                  [2560x1440, 640x360, 854x480]
# 26                  [2560x1440, 640x360, 854x480]
# 25                  [2560x1440, 640x360, 854x480]
# 23                           [2560x1440, 640x360]
# 20                           [2560x1440, 640x360]
# 24                  [2560x1440, 640x360, 854x480]
# 21                  [2560x1440, 640x360, 854x480]
# 22                           [2560x1440, 640x360]
# 39  [0x0, 2560x1440, 3840x2160, 640x360, 854x480]
# 47       [2560x1440, 3840x2160, 640x360, 854x480]
# 46       [1920x1080, 3840x2160, 640x360, 854x480]
# 45  [0x0, 2560x1440, 3840x2160, 640x360, 854x480]
# 43                [2560x1440, 3840x2160, 640x360]
# 40       [2560x1440, 3840x2160, 640x360, 854x480]
# 44       [2560x1440, 3840x2160, 640x360, 854x480]
# 41  [0x0, 2560x1440, 3840x2160, 640x360, 854x480]
# 42  [0x0, 2560x1440, 3840x2160, 640x360, 854x480]

# %%
df_curr_quality = df_nerd_stats_with_meta.groupby(['player_dimensions', 'suggested_quality'], as_index=False).agg({'current_res':lambda x: list(set(x))})
df_curr_quality['player_dimensions'] = pd.Categorical(df_curr_quality['player_dimensions'], 
            ['256x144', '426x240', '640x360', '854x480', '1280x720', '1920x1080', '2560x1440', '3840x2160'])
df_curr_quality['suggested_quality'] = pd.Categorical(df_curr_quality['suggested_quality'], 
            ['auto', 'tiny', 'small', 'medium', 'large', 'hd720', 'hd1080', 'highres', 'hd1440', 'hd2160'])
df_curr_quality.sort_values(['player_dimensions', 'suggested_quality'])
# Out:
#    player_dimensions suggested_quality  \
# 29           256x144              auto
# 38           256x144              tiny
# 37           256x144             small
# 36           256x144            medium
# 35           256x144             large
# 33           256x144             hd720
# 30           256x144            hd1080
# 34           256x144           highres
# 31           256x144            hd1440
# 32           256x144            hd2160
# 48           426x240              auto
# 57           426x240              tiny
# 56           426x240             small
# 55           426x240            medium
# 54           426x240             large
# 52           426x240             hd720
# 49           426x240            hd1080
# 53           426x240           highres
# 50           426x240            hd1440
# 51           426x240            hd2160
# 58           640x360              auto
# 67           640x360              tiny
# 66           640x360             small
# 65           640x360            medium
# 64           640x360             large
# 62           640x360             hd720
# 59           640x360            hd1080
# 63           640x360           highres
# 60           640x360            hd1440
# 61           640x360            hd2160
# 68           854x480              auto
# 76           854x480             small
# 75           854x480            medium
# 74           854x480             large
# 72           854x480             hd720
# 69           854x480            hd1080
# 73           854x480           highres
# 70           854x480            hd1440
# 71           854x480            hd2160
# 0           1280x720              auto
# 8           1280x720              tiny
# 7           1280x720             small
# 6           1280x720             large
# 4           1280x720             hd720
# 1           1280x720            hd1080
# 5           1280x720           highres
# 2           1280x720            hd1440
# 3           1280x720            hd2160
# 9          1920x1080              auto
# 18         1920x1080              tiny
# 17         1920x1080             small
# 16         1920x1080            medium
# 15         1920x1080             large
# 13         1920x1080             hd720
# 10         1920x1080            hd1080
# 14         1920x1080           highres
# 11         1920x1080            hd1440
# 12         1920x1080            hd2160
# 19         2560x1440              auto
# 28         2560x1440              tiny
# 27         2560x1440             small
# 26         2560x1440            medium
# 25         2560x1440             large
# 23         2560x1440             hd720
# 20         2560x1440            hd1080
# 24         2560x1440           highres
# 21         2560x1440            hd1440
# 22         2560x1440            hd2160
# 39         3840x2160              auto
# 47         3840x2160              tiny
# 46         3840x2160             small
# 45         3840x2160            medium
# 43         3840x2160             hd720
# 40         3840x2160            hd1080
# 44         3840x2160           highres
# 41         3840x2160            hd1440
# 42         3840x2160            hd2160
#
#                                       current_res
# 29                                      [640x360]
# 38                                      [640x360]
# 37                                      [640x360]
# 36                                      [640x360]
# 35                                      [640x360]
# 33                                 [0x0, 640x360]
# 30                                      [640x360]
# 34                                      [640x360]
# 31                                      [640x360]
# 32                                      [640x360]
# 48                             [426x240, 640x360]
# 57                                      [640x360]
# 56                                      [640x360]
# 55                                      [640x360]
# 54                                      [640x360]
# 52                                      [640x360]
# 49                                      [640x360]
# 53                                      [640x360]
# 50                                      [640x360]
# 51                                      [640x360]
# 58                                      [640x360]
# 67                                      [640x360]
# 66                                      [640x360]
# 65                                      [640x360]
# 64                                      [640x360]
# 62                                 [0x0, 640x360]
# 59                                      [640x360]
# 63                                      [640x360]
# 60                                      [640x360]
# 61                                      [640x360]
# 68                             [640x360, 854x480]
# 76                             [640x360, 854x480]
# 75                             [640x360, 854x480]
# 74                             [640x360, 854x480]
# 72                             [640x360, 854x480]
# 69                             [640x360, 854x480]
# 73                             [640x360, 854x480]
# 70                             [640x360, 854x480]
# 71                             [640x360, 854x480]
# 0                    [1280x720, 640x360, 854x480]
# 8                    [1280x720, 640x360, 854x480]
# 7                    [1280x720, 640x360, 854x480]
# 6                    [1280x720, 640x360, 854x480]
# 4                    [1280x720, 640x360, 854x480]
# 1                    [1280x720, 640x360, 854x480]
# 5                    [1280x720, 640x360, 854x480]
# 2                    [1280x720, 640x360, 854x480]
# 3                    [1280x720, 640x360, 854x480]
# 9                   [640x360, 1920x1080, 854x480]
# 18                  [640x360, 1920x1080, 854x480]
# 17                  [640x360, 1920x1080, 854x480]
# 16                  [640x360, 1920x1080, 854x480]
# 15                  [640x360, 1920x1080, 854x480]
# 13                  [640x360, 1920x1080, 854x480]
# 10             [0x0, 640x360, 1920x1080, 854x480]
# 14                  [640x360, 1920x1080, 854x480]
# 11                  [640x360, 1920x1080, 854x480]
# 12                  [640x360, 1920x1080, 854x480]
# 19                  [2560x1440, 640x360, 854x480]
# 28                  [2560x1440, 640x360, 854x480]
# 27                  [2560x1440, 640x360, 854x480]
# 26                  [2560x1440, 640x360, 854x480]
# 25                  [2560x1440, 640x360, 854x480]
# 23                           [2560x1440, 640x360]
# 20                           [2560x1440, 640x360]
# 24                  [2560x1440, 640x360, 854x480]
# 21                  [2560x1440, 640x360, 854x480]
# 22                           [2560x1440, 640x360]
# 39  [3840x2160, 854x480, 0x0, 2560x1440, 640x360]
# 47       [2560x1440, 640x360, 3840x2160, 854x480]
# 46       [640x360, 1920x1080, 854x480, 3840x2160]
# 45  [3840x2160, 854x480, 0x0, 2560x1440, 640x360]
# 43                [2560x1440, 640x360, 3840x2160]
# 40       [2560x1440, 640x360, 3840x2160, 854x480]
# 44       [2560x1440, 640x360, 3840x2160, 854x480]
# 41  [3840x2160, 854x480, 0x0, 2560x1440, 640x360]
# 42  [3840x2160, 854x480, 0x0, 2560x1440, 640x360]

# %%
measurements.video_ids.unique()
# Out:
# array(['aqz-KE-bpKQ, lqiN98z6Dak, RJnKaAtBPhA'], dtype=object)

# %%
df_nerd_stats_resolutions.msm_id.nunique()
# Out:
# 599

# %%
df_nerd_stats_resolutions
# Out:
#                                    msm_id                   resolution  \
# 0    24fdef1c-a087-9736-abf0-4913a80e3f88      640x360@30 / 640x360@30
# 1    7618731e-77bb-398c-804f-8749bd91e64e      640x360@30 / 640x360@30
# 2    08a69630-1ba1-f7b7-9772-85bab6baa8bd      640x360@24 / 640x360@24
# 3    72a7b5e0-9b49-0569-7eb7-bfe57806c0af      640x360@24 / 640x360@24
# 4    71f797b6-e500-e0e3-b922-41aca902dd43      640x360@30 / 640x360@30
# ..                                    ...                          ...
# 749  d00dd8dc-b80c-54f1-d80c-678f8c42ff6f    854x480@24 / 3840x2160@24
# 750  d00dd8dc-b80c-54f1-d80c-678f8c42ff6f  3840x2160@24 / 3840x2160@24
# 751  88557a9e-8aae-37f8-0380-fd547aac23eb      640x360@24 / 640x360@24
# 752  9ad2baf1-6ac9-0f76-2bb2-22a64f50c21d    854x480@24 / 3840x2160@24
# 753  9ad2baf1-6ac9-0f76-2bb2-22a64f50c21d  3840x2160@24 / 3840x2160@24
#
#     current_res optimal_res
# 0       640x360     640x360
# 1       640x360     640x360
# 2       640x360     640x360
# 3       640x360     640x360
# 4       640x360     640x360
# ..          ...         ...
# 749     854x480   3840x2160
# 750   3840x2160   3840x2160
# 751     640x360     640x360
# 752     854x480   3840x2160
# 753   3840x2160   3840x2160
#
# [754 rows x 4 columns]

# %%
df_nerd_stats_resolutions[df_nerd_stats_resolutions.current_res == df_nerd_stats_resolutions.optimal_res].msm_id.nunique()
# Out:
# 599

# %%
df_start_time
# Out:
#                        start_time                     play_time  \
# 0   2022-02-16 18:18:17.404700160 2022-02-16 18:18:17.760900096
# 1   2022-02-16 18:18:24.888299776 2022-02-16 18:18:25.234500096
# 2   2022-02-16 18:19:00.551600128 2022-02-16 18:19:01.182200320
# 3   2022-02-16 18:19:08.676100096 2022-02-16 18:19:08.951300096
# 4   2022-02-16 18:19:49.226800128 2022-02-16 18:19:49.738099968
# ..                            ...                           ...
# 637 2022-02-16 22:05:59.963300096 2022-02-16 22:06:29.036699904
# 638 2022-02-16 22:06:36.206700032 2022-02-16 22:06:36.494600192
# 639 2022-02-16 22:06:43.761100032 2022-02-16 22:06:44.088999936
# 640 2022-02-16 22:07:20.705299712 2022-02-16 22:07:21.040099840
# 641 2022-02-16 22:07:28.192499968 2022-02-16 22:07:28.579500032
#
#                                    msm_id  startup_delay
# 0    24fdef1c-a087-9736-abf0-4913a80e3f88         0.3562
# 1    7618731e-77bb-398c-804f-8749bd91e64e         0.3462
# 2    08a69630-1ba1-f7b7-9772-85bab6baa8bd         0.6306
# 3    72a7b5e0-9b49-0569-7eb7-bfe57806c0af         0.2752
# 4    71f797b6-e500-e0e3-b922-41aca902dd43         0.5113
# ..                                    ...            ...
# 637  588a971c-87c2-5f5c-e0d5-795b7aa4c308        29.0734
# 638  1ab93042-62b8-1d71-b39b-291b3f0520b7         0.2879
# 639  d00dd8dc-b80c-54f1-d80c-678f8c42ff6f         0.3279
# 640  88557a9e-8aae-37f8-0380-fd547aac23eb         0.3348
# 641  9ad2baf1-6ac9-0f76-2bb2-22a64f50c21d         0.3870
#
# [642 rows x 4 columns]

# %%
df_start_time_with_meta = pd.merge(df_start_time[['startup_delay', 'msm_id']], measurements[measurements.cacheWarming == 0][['msm_id', 'player_dimensions']], on='msm_id')

# %%
df_start_time_with_meta
# Out:
#      startup_delay                                msm_id player_dimensions
# 0           0.3462  7618731e-77bb-398c-804f-8749bd91e64e           256x144
# 1           0.2752  72a7b5e0-9b49-0569-7eb7-bfe57806c0af           256x144
# 2           0.3481  8a6fb38e-8f4f-0275-3e7c-12b563639378           256x144
# 3           0.2848  fca714c4-b0d0-4c40-fcf8-eb78e6443bc6           256x144
# 4           0.4749  26749509-3fae-0048-7ed4-94ea874cbed3           256x144
# ..             ...                                   ...               ...
# 289         0.4112  195a10e6-a725-5d98-22d5-ee199b9d94a2         3840x2160
# 290         0.3485  9e9c4de3-4b3f-5843-8cb3-ad3ed84cf033         3840x2160
# 291         0.3836  588a971c-87c2-5f5c-e0d5-795b7aa4c308         3840x2160
# 292         0.3279  d00dd8dc-b80c-54f1-d80c-678f8c42ff6f         3840x2160
# 293         0.3870  9ad2baf1-6ac9-0f76-2bb2-22a64f50c21d         3840x2160
#
# [294 rows x 3 columns]

# %%
df_start_time_with_meta.player_dimensions.unique()
# Out:
# array(['256x144', '426x240', '640x360', '854x480', '1280x720',
#        '1920x1080', '2560x1440', '3840x2160'], dtype=object)

# %%
colors = dict(zip(list(df_start_time_with_meta.player_dimensions.unique()), ['C0','C1','C2','C3','C4','C5','C6','C7']))

markers = dict(zip(list(df_start_time_with_meta.player_dimensions.unique()), ['o','v','^','>','s','p','h','d']))

# %%
lnwidth = .5
mrksize = 3
figname = 'test'
for log in [True, False]:
    fig, ax = plt.subplots(figsize=(5,2))
    for resolution in df_start_time_with_meta.player_dimensions.unique():
        cdf = Cdf.MakeCdfFromList(df_start_time_with_meta[df_start_time_with_meta.player_dimensions == resolution]['startup_delay'])
        ax.plot(cdf.xs, cdf.ps, label=resolution,
                    linestyle='-', linewidth=lnwidth, 
                    markersize=mrksize, fillstyle='none', 
                    markevery=max(1, int(len(cdf.xs)/10)), drawstyle="default",
                    color=colors[resolution], marker=markers[resolution]
                   )


    
    #else:
    #ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x,y: human_format(x)))
    #if log:
    #    ax.xaxis.set_major_formatter(PercentFormatter(xmax = 1.0, decimals=1))
    #else:
    ax.yaxis.set_major_formatter(PercentFormatter(xmax = 1.0))

    ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')
    ax.yaxis.set_ticks_position('left')
    ax.xaxis.set_ticks_position('bottom')
    ax.spines['bottom'].set_position(('axes', -0.0))
    ax.spines['left'].set_position(('axes', -0.0))

    if not log:
        #ax.legend(loc='center', ncol=1, markerscale=10, bbox_to_anchor=(0.5, -.6))
        ax.legend(loc='lower right', ncol=3, markerscale=2)
    else:
        ax.set_xscale('log')
        #ax.set_xscale('symlog')
        ax.legend(loc='lower right', ncol=2, markerscale=2, bbox_to_anchor=(.8, -.85))

    ax.xaxis.set_major_formatter(ticker.StrMethodFormatter("{x:g}"))


    ax.set_title("")

    ax.set_xlabel("startup delay? [seconds]")

    ax.set_ylabel("CDF")
    #ax.set_xlim(0.1,100)


    #if log:
    #    fig.savefig(figname+'-log.pdf', format='pdf', bbox_inches='tight')
    #else:
    #    fig.savefig(figname+'.pdf', format='pdf', bbox_inches='tight')
    plt.show()

# %%
df_buffering = pd.read_sql_query("""
SELECT time, msm_id, curr_play_time, current_quality FROM iframe_api WHERE event_type = 'PlayerStateBUFFERING'
""", conn)

# %%
df_buffering
# Out:
#              time                                msm_id  curr_play_time  \
# 0    1.645035e+12  24fdef1c-a087-9736-abf0-4913a80e3f88        0.000000
# 1    1.645036e+12  7618731e-77bb-398c-804f-8749bd91e64e        0.000000
# 2    1.645036e+12  08a69630-1ba1-f7b7-9772-85bab6baa8bd        0.000000
# 3    1.645036e+12  72a7b5e0-9b49-0569-7eb7-bfe57806c0af        0.000000
# 4    1.645036e+12  71f797b6-e500-e0e3-b922-41aca902dd43        0.000000
# ..            ...                                   ...             ...
# 648  1.645049e+12  588a971c-87c2-5f5c-e0d5-795b7aa4c308       23.054609
# 649  1.645049e+12  1ab93042-62b8-1d71-b39b-291b3f0520b7        0.000000
# 650  1.645049e+12  d00dd8dc-b80c-54f1-d80c-678f8c42ff6f        0.000000
# 651  1.645049e+12  88557a9e-8aae-37f8-0380-fd547aac23eb        0.000000
# 652  1.645049e+12  9ad2baf1-6ac9-0f76-2bb2-22a64f50c21d        0.000000
#
#     current_quality
# 0           unknown
# 1           unknown
# 2           unknown
# 3           unknown
# 4           unknown
# ..              ...
# 648          hd2160
# 649         unknown
# 650         unknown
# 651         unknown
# 652         unknown
#
# [653 rows x 4 columns]

# %%
df_buffering_with_meta = pd.merge(df_buffering, measurements[measurements.cacheWarming == 0][['msm_id', 'player_dimensions', 'domain']], on='msm_id')

# %%
df_buffering_with_meta[df_buffering_with_meta.curr_play_time != 0.].current_quality.unique()
# Out:
# array(['hd1440', 'hd2160'], dtype=object)

# %%
colors = dict(zip(['hd1440', 'hd2160'], ['C0','C1']))
markers = dict(zip(['hd1440', 'hd2160'], ['o','v']))
lnwidth = .5
mrksize = 3
figname = 'test'
for log in [False]:
    fig, ax = plt.subplots(figsize=(5,2))
    df_plt = df_buffering_with_meta[df_buffering_with_meta.curr_play_time != 0.]
    for quality in df_plt.current_quality.unique():
        cdf = Cdf.MakeCdfFromList(df_plt[df_plt.current_quality == quality]['curr_play_time'])
        ax.plot(cdf.xs, cdf.ps, label=quality,
                    linestyle='-', linewidth=lnwidth, 
                    markersize=mrksize, fillstyle='none', 
                    markevery=max(1, int(len(cdf.xs)/10)), drawstyle="default",
                    color=colors[quality], marker=markers[quality]
                   )


    
    #else:
    #ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x,y: human_format(x)))
    #if log:
    #    ax.xaxis.set_major_formatter(PercentFormatter(xmax = 1.0, decimals=1))
    #else:
    ax.yaxis.set_major_formatter(PercentFormatter(xmax = 1.0))

    ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')
    ax.yaxis.set_ticks_position('left')
    ax.xaxis.set_ticks_position('bottom')
    ax.spines['bottom'].set_position(('axes', -0.0))
    ax.spines['left'].set_position(('axes', -0.0))

    #if not log:
        #ax.legend(loc='center', ncol=1, markerscale=10, bbox_to_anchor=(0.5, -.6))
    ax.legend(loc='lower right', ncol=3, markerscale=2)
    if log:
        ax.set_xscale('log')
        #ax.set_xscale('symlog')
        #ax.legend(loc='lower right', ncol=2, markerscale=2, bbox_to_anchor=(.8, -.85))

    ax.xaxis.set_major_formatter(ticker.StrMethodFormatter("{x:g}"))


    ax.set_title("")

    ax.set_xlabel("playback time when buffering occurred [seconds]")

    ax.set_ylabel("CDF")


    #if log:
    #    fig.savefig(figname+'-log.pdf', format='pdf', bbox_inches='tight')
    #else:
    #    fig.savefig(figname+'.pdf', format='pdf', bbox_inches='tight')
    plt.show()

# %%
df_buffering_with_meta[(df_buffering_with_meta.curr_play_time >= 30.) & (df_buffering_with_meta.current_quality == 'hd1440')].domain.unique()
# Out:
# array(['aqz-KE-bpKQ'], dtype=object)

# %%
df_buffering_with_meta[(df_buffering_with_meta.curr_play_time < 20.) & (df_buffering_with_meta.curr_play_time > 15.) & (df_buffering_with_meta.current_quality == 'hd1440')].domain.unique()
# Out:
# array(['aqz-KE-bpKQ'], dtype=object)

# %%
df_buffering_with_meta[df_buffering_with_meta.curr_play_time != 0.].domain.value_counts()
# Out:
# aqz-KE-bpKQ    54
# Name: domain, dtype: int64

# %%
df_buffering_with_meta[df_buffering_with_meta.curr_play_time == 0.].domain.value_counts()
# Out:
# aqz-KE-bpKQ    106
# lqiN98z6Dak     99
# RJnKaAtBPhA     89
# Name: domain, dtype: int64

# %%
measurements[measurements.cacheWarming == 0].domain.value_counts()
# Out:
# aqz-KE-bpKQ    108
# lqiN98z6Dak     99
# RJnKaAtBPhA     90
# Name: domain, dtype: int64

# %%
df_test = df_nerd_stats_with_meta.groupby(['player_dimensions', 'suggested_quality', 'domain'], as_index=False).agg(optimal_res_count=('optimal_res',lambda x: len(list(set(x)))), optimal_res_list=('optimal_res', lambda x: list(set(x))))
print(df_test[df_test.optimal_res_count > 1].optimal_res_list.astype(str).unique())
print(df_test[df_test.optimal_res_count > 1].domain.unique())
# Out:
# ["['2560x1440', '3840x2160']"]
# ['aqz-KE-bpKQ']

# %%
df_test
# Out:
#     player_dimensions suggested_quality       domain  optimal_res_count  \
# 0            1280x720              auto  RJnKaAtBPhA                  1
# 1            1280x720              auto  aqz-KE-bpKQ                  1
# 2            1280x720              auto  lqiN98z6Dak                  1
# 3            1280x720            hd1080  RJnKaAtBPhA                  1
# 4            1280x720            hd1080  aqz-KE-bpKQ                  1
# ..                ...               ...          ...                ...
# 210           854x480            medium  aqz-KE-bpKQ                  1
# 211           854x480            medium  lqiN98z6Dak                  1
# 212           854x480             small  RJnKaAtBPhA                  1
# 213           854x480             small  aqz-KE-bpKQ                  1
# 214           854x480             small  lqiN98z6Dak                  1
#
#     optimal_res_list
# 0         [1280x720]
# 1         [1280x720]
# 2         [1280x720]
# 3         [1280x720]
# 4         [1280x720]
# ..               ...
# 210        [854x480]
# 211        [854x480]
# 212        [854x480]
# 213        [854x480]
# 214        [854x480]
#
# [215 rows x 5 columns]

# %%
conn2 = sqlite3.connect('../web-performance/web-performance-youtube1.db')

# %%
df_test = pd.read_sql_query("SELECT * FROM page_resources", conn2)

# %%
df_test[~df_test.name.str.startswith('https://rr2---sn-4g5ednly.googlevideo.com')].msm_id.unique()
# Out:
# array(['4c8336dc-c62b-4a0d-b451-1a8c110abd4c',
#        '366f0dc0-97b2-81dc-5d97-7b99fc1fcce0',
#        '2bc2fa62-ef50-3f15-b0a9-ac961e7f4fe8',
#        '97d20a8f-fb8a-12ae-a90d-d43b7a0ebe5a',
#        '09d5dc97-2250-d5db-3b80-9c90322758b8',
#        '5267ae21-153a-01a5-626e-c8e289a500de',
#        '10303bb9-d231-f785-b440-f07252c58b81',
#        'b0330613-610e-89ca-b45f-255588a3840a',
#        '66333ff4-7c9e-9fab-cb21-6bc9c90fab93',
#        'f3c4f02f-10d0-52c3-37ad-7676df2d4533',
#        '0629ed87-3121-da48-fd62-00ad0818d8b0',
#        'd4b2f803-3d36-f043-c737-4c0c94e94a92',
#        'a8cd71f3-a4da-6c89-8755-933a970b2f8c',
#        '0349418b-d493-cc50-bc63-1a95613abcfe',
#        '0ac9103e-144c-21d7-ac84-a1ef7d102692',
#        '1268731d-7f27-df83-c687-0aa00ddd43cd',
#        'b44750de-470d-f167-edce-3bf30f3f36ee'], dtype=object)

# %%
df_test[df_test.name.str.startswith('https://rr2---sn-4g5ednly.googlevideo.com')].msm_id.unique()
# Out:
# array(['6d642514-7b6e-d164-abb5-f46881396522',
#        '5ca121c7-9d07-936d-9cad-204b6939fa2e',
#        '228d58a3-b2a6-e4ae-8089-0aa778a93627',
#        '33c5e094-805e-ab10-235a-62def2423a7a',
#        'ac6fd294-c00d-0faf-cbeb-067c5c388e37',
#        'a33eb031-98f2-c794-f8e8-34ef63cf04d3',
#        'e7159b0f-cd46-a8fe-8479-4a2a91c66864',
#        'ede390ed-05ae-5d16-daa0-12f4bd598c1a',
#        'c6c8741c-feb5-3a0a-ec38-5a151252d600',
#        '720b66a5-0301-aa3a-7b90-29ff905d47c6',
#        '31e5c91d-23bb-8eff-eb80-4a9df8d5b83d',
#        '0de6e2b9-3e54-f19f-c0d1-28b52a30e663',
#        'b4aedd54-2543-078c-cde2-4ef1b5bdc74d',
#        'a7923bbc-fc82-c882-9d81-d6c6bdf87400',
#        'c63ef478-a2d5-e823-a30a-7e0b6afe2352',
#        '1ca67a60-705f-ee6c-5a9d-450909f788c8',
#        'dfd7e3b0-fe55-003c-95ba-c3c7e90481f0',
#        '25733fbe-9102-cf0c-901e-324e9f25d459',
#        '0ff39917-9970-3ff5-a155-733d221ae271',
#        'c1f61852-e085-1fb7-37d8-53c7f67c3999',
#        'a1e9aef6-1f11-086b-b9e3-cac10a5c0e7f',
#        '341f3b9f-f1be-d8e6-a753-caa28434e648',
#        'c35a6ae8-b414-fada-b6df-1d0ca052213f'], dtype=object)

# %%
df_test[(~df_test.name.str.startswith('https://rr2---sn-4g5ednly.googlevideo.com')) & ~(df_test.name.str.startswith('https://rr2---sn-4g5lzner.googlevideo.com')) & (~df_test.name.str.startswith('https://rr1---sn-1gi7znek.googlevideo.com'))]
# Out:
# Empty DataFrame
# Columns: [connectEnd, connectStart, decodedBodySize, domainLookupEnd, domainLookupStart, duration, encodedBodySize, entryType, fetchStart, initiatorType, name, nextHopProtocol, requestStart, responseEnd, responseStart, secureConnectionStart, startTime, transferSize, msm_id]
# Index: []

# %%
df_test['googlevideo'] = df_test.name.str.split('/').str[2]

# %%
df_test.googlevideo.unique()
# Out:
# array(['rr2---sn-4g5ednly.googlevideo.com',
#        'rr2---sn-4g5lzner.googlevideo.com',
#        'rr1---sn-1gi7znek.googlevideo.com'], dtype=object)

# %%
df_test_msm = pd.read_sql_query("SELECT * FROM measurements", conn2)
df_test_msm['player_width'] = df_test_msm['player_width'].astype(str)
df_test_msm['player_height'] = df_test_msm['player_height'].astype(str)
df_test_msm['player_dimensions'] = df_test_msm['player_width']+"x"+df_test_msm['player_height']

# %%
df_test = pd.merge(df_test, df_test_msm[['msm_id', 'cacheWarming', 'player_dimensions']])

# %%
df_test.groupby(['player_dimensions', 'googlevideo']).agg({'cacheWarming':lambda x: list(set(x))})
# Out:
#                                                     cacheWarming
# player_dimensions googlevideo
# 1280x720          rr2---sn-4g5ednly.googlevideo.com       [0, 1]
#                   rr2---sn-4g5lzner.googlevideo.com       [0, 1]
# 1920x1080         rr1---sn-1gi7znek.googlevideo.com          [0]
#                   rr2---sn-4g5ednly.googlevideo.com       [0, 1]
#                   rr2---sn-4g5lzner.googlevideo.com       [0, 1]
# 2560x1440         rr2---sn-4g5ednly.googlevideo.com       [0, 1]
#                   rr2---sn-4g5lzner.googlevideo.com       [0, 1]
# 3840x2160         rr2---sn-4g5ednly.googlevideo.com       [0, 1]
#                   rr2---sn-4g5lzner.googlevideo.com       [0, 1]

# %%
df_test_iframe = pd.read_sql_query("SELECT * FROM iframe_api", conn2)

# %%
df_test_iframe = pd.merge(df_test_iframe, df_test_msm[['msm_id', 'cacheWarming', 'player_dimensions']])

# %%
df_test_iframe[(df_test_iframe.event_type == 'PlayerStatePLAYING') & (df_test_iframe.curr_play_time < 1) & (df_test_iframe.curr_play_time >= 0)].groupby('player_dimensions').agg({'current_quality':pd.Series.unique})
# Out:
#                             current_quality
# player_dimensions
# 1280x720                              hd720
# 1920x1080                  [hd1080, medium]
# 2560x1440                  [hd1440, hd1080]
# 3840x2160          [hd1440, hd2160, hd1080]

# %%
df_test_iframe[(df_test_iframe.event_type == 'PlayerStatePLAYING')].curr_play_time.describe()
# Out:
# count    71.000000
# mean      8.154860
# std       9.798265
# min       0.006406
# 25%       0.020400
# 50%       0.027621
# 75%      19.328500
# max      28.227739
# Name: curr_play_time, dtype: float64
